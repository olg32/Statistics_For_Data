# %%
import numpy as np
from scipy.stats import binom
two_c = np.random.binomial(2,0.5,100)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')
sns.countplot(x=two_c)
plt.show()

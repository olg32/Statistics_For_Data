# %% [markdown]
# ## Poisson Distribution using Scipy

# %%
from scipy.stats import poisson

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from scipy.stats import poisson

# %%
poisson.pmf(7,3.6)
# Out:
# 0.04248414026930935

# %%
poisson.cdf(7,3.6)
# Out:
# 0.9692107246403425

# %% [markdown]
# ## Probability of getting more than 7 persons in queue

# %%
poisson.sf(7,3.6)
# Out:
# 0.030789275359657444

# %%
import numpy as np

# %%
x_ax=np.arange(0,11)

# %%
y_ax=poisson.pmf(x_ax,3.6)

# %%
sns.barplot(x=x_ax, y=y_ax)
plt.show()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style='whitegrid')
sns.barplot(x=x_ax, y=y_ax)
plt.show()

# %%
y_ax=poisson.cdf(x_ax,3.6)

# %%
sns.barplot(x=x_ax, y=y_ax)
plt.show()

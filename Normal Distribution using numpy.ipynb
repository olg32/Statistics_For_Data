# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.normal(100,2)
# Out:
# 97.26546593123955

# %%
np.random.normal(100,2,10)
# Out:
# array([ 97.15436358,  97.78021481, 100.85446402, 100.39220458,
#         96.42210139,  99.38268107, 101.40408467,  96.77357697,
#         98.65407855,  98.79954868])

# %%
np.round(np.random.normal(100,2,10),2)
# Out:
# array([101.56, 101.68, 103.3 ,  98.64,  96.37,  95.53,  97.67,  95.45,
#        102.77,  97.94])

# %%
sns.set_theme(style="whitegrid")
a=np.random.normal(100,2, 1000)
sns.histplot(x=a)
plt.show()

# %%
sns.set_theme(style="whitegrid")
a=np.random.normal(100,2, 1000000)
sns.histplot(x=a, kde=True)
plt.show()
